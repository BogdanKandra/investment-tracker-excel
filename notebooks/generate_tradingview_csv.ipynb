# %% [markdown]
# ***Generate a CSV file for importing the investment portfolio saved in the `portfolio.json` file into TradingView***

# %% [markdown]
# ### Imports

# %%
import subprocess
from pathlib import Path

# %% [markdown]
# ### Set paths

# %%
PROJECT_PATH = Path.cwd().parent
GENERATION_SCRIPT_PATH = PROJECT_PATH / "src" / "csv_generators" / "tradingview.py"

# %% [markdown]
# ### Generate the TradingView import CSV file

# %%
commands = ["python", GENERATION_SCRIPT_PATH]

process = subprocess.run(
    commands,
    capture_output=True,
    text=True
)

print(process.stdout)
